# %%
# !pip install tqdm scipy --quiet

from google.colab import drive
import os
from datetime import datetime

drive.mount('/content/drive', force_remount=False)

# 🔁 change this to your real path in Drive:
# %cd /content/drive/MyDrive/Diffusion_Model/frequency_update_v1/
# !ls

# Create a timestamp like: 2025-12-12_16-40-55
timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
output_dir = f"/content/drive/MyDrive/Diffusion_Model/frequency_update_v1/output/freq_2_16_32____{timestamp}"
os.makedirs(output_dir, exist_ok=True)
print("Created output directory:", output_dir)
# === Export this folder path as an environment variable ===
os.environ["DM_OUTPUT_DIR"] = output_dir



#Start training the Diffusion model
#!python train.py
#!python train_A_than_B_freq.py

#!python train_A_than_B_freq_1_4_16.py   #1
#!python train_A_than_B_freq_1_4_8.py    #2
#!python train_A_than_B_freq_1_2_8.py    #3
#!python train_A_than_B_freq_2_4_8.py    #4
#!python train_A_than_B_freq_1_8_16.py   #5
# !python train_A_than_B_freq_2_16_32.py  #6
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Diffusion_Model/frequency_update_v1
# data	     run_diffusion_modules.ipynb    train_A_than_B_freq_2_16_32.py
# network.py   train_A_than_B_freq_1_2_8.py   train_A_than_B_freq_2_4_8.py
# output	     train_A_than_B_freq_1_4_16.py  train_A_than_B_freq.py
# predict.py   train_A_than_B_freq_1_4_8.py
# __pycache__  train_A_than_B_freq_1_8_16.py
# Created output directory: /content/drive/MyDrive/Diffusion_Model/frequency_update_v1/output/freq_2_16_32____2026-01-10_17-21-05
# [train_two_phase_continual] Saving output to: /content/drive/MyDrive/Diffusion_Model/frequency_update_v1/output/freq_2_16_32____2026-01-10_17-21-05
# ========== TRAINING (train_on_digits) ==========
# digits              : [0, 1, 2, 3, 4, 5]
# pretrained_path     : None
# early_stop_loss     : 0.025
# n_epoch             : 100
# batch_size          : 256
# ...
